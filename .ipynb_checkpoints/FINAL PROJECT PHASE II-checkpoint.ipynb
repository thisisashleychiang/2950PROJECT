# %% [markdown]
# # FINAL PROJECT PHASE II

# %% [markdown]
# ## Research Question:
#
# ### Question:
# **Correlation between the user experience and the willingness to purchase products;** 1) Is there a correlation between the user experience (helpful review, helpful recommendation, personalized product recommendations) and the frequency of cart completion? 2) Is there a correlation between the user experience (helpful review, helpful recommendation, personalized product recommendations) and the frequency of adding items to cart? 3) Patterns among different categories in different age groups.
#
#
#
# +explain in detail

# %%
#import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from sklearn.linear_model import LinearRegression, LogisticRegression
import duckdb

# %% [markdown]
# ## Data Overview:
#
# +description

# %%
#import packages and read csv file
df=pd.read_csv("/Users/ashleychiang/2950PROJECT/Amazon Customer Behavior Survey.csv",thousands=",")

print(df.shape)
df.head()
# Out:
# (602, 23)
#                         Timestamp  age             Gender  \
# 0  2023/06/04 1:28:19 PM GMT+5:30   23             Female
# 1  2023/06/04 2:30:44 PM GMT+5:30   23             Female
# 2  2023/06/04 5:04:56 PM GMT+5:30   24  Prefer not to say
# 3  2023/06/04 5:13:00 PM GMT+5:30   24             Female
# 4  2023/06/04 5:28:06 PM GMT+5:30   22             Female
#
#        Purchase_Frequency                                Purchase_Categories  \
# 0       Few times a month                           Beauty and Personal Care
# 1            Once a month                               Clothing and Fashion
# 2       Few times a month    Groceries and Gourmet Food;Clothing and Fashion
# 3            Once a month  Beauty and Personal Care;Clothing and Fashion;...
# 4  Less than once a month      Beauty and Personal Care;Clothing and Fashion
#
#   Personalized_Recommendation_Frequency Browsing_Frequency  \
# 0                                   Yes   Few times a week
# 1                                   Yes  Few times a month
# 2                                    No  Few times a month
# 3                             Sometimes  Few times a month
# 4                                   Yes  Few times a month
#
#   Product_Search_Method Search_Result_Exploration  \
# 0               Keyword            Multiple pages
# 1               Keyword            Multiple pages
# 2               Keyword            Multiple pages
# 3               Keyword                First page
# 4                Filter            Multiple pages
#
#    Customer_Reviews_Importance  ... Saveforlater_Frequency Review_Left  \
# 0                            1  ...              Sometimes         Yes
# 1                            1  ...                 Rarely          No
# 2                            2  ...                 Rarely          No
# 3                            5  ...              Sometimes         Yes
# 4                            1  ...                 Rarely          No
#
#   Review_Reliability Review_Helpfulness  \
# 0       Occasionally                Yes
# 1            Heavily                Yes
# 2       Occasionally                 No
# 3            Heavily                Yes
# 4            Heavily                Yes
#
#   Personalized_Recommendation_Frequency  Recommendation_Helpfulness  \
# 0                                      2                        Yes
# 1                                      2                  Sometimes
# 2                                      4                         No
# 3                                      3                  Sometimes
# 4                                      4                        Yes
#
#   Rating_Accuracy   Shopping_Satisfaction    Service_Appreciation  \
# 0                1                      1      Competitive prices
# 1                3                      2  Wide product selection
# 2                3                      3      Competitive prices
# 3                3                      4      Competitive prices
# 4                2                      2      Competitive prices
#
#               Improvement_Areas
# 0      Reducing packaging waste
# 1      Reducing packaging waste
# 2  Product quality and accuracy
# 3  Product quality and accuracy
# 4  Product quality and accuracy
#
# [5 rows x 23 columns]

# %% [markdown]
# ## DATA CLEANING:

# %%
#we created a new dataframe that is relevant to our research question.

new_df= duckdb.sql('''

SELECT age, Review_Helpfulness, Recommendation_Helpfulness, 
Personalized_Recommendation_Frequency, Cart_Completion_Frequency, 
Add_to_Cart_Browsing, Customer_Reviews_Importance
FROM df

''').df()

new_df.head()
# Out:
#    age Review_Helpfulness Recommendation_Helpfulness  \
# 0   23                Yes                        Yes
# 1   23                Yes                  Sometimes
# 2   24                 No                         No
# 3   24                Yes                  Sometimes
# 4   22                Yes                        Yes
#
#   Personalized_Recommendation_Frequency Cart_Completion_Frequency  \
# 0                                   Yes                 Sometimes
# 1                                   Yes                     Often
# 2                                    No                 Sometimes
# 3                             Sometimes                 Sometimes
# 4                                   Yes                 Sometimes
#
#   Add_to_Cart_Browsing  Customer_Reviews_Importance
# 0                  Yes                            1
# 1                  Yes                            1
# 2                  Yes                            2
# 3                Maybe                            5
# 4                  Yes                            1

# %%
#We changed the values from string to numbers so that we can actually measure the correlation. 


new_df['New_Review_Helpfulness']=new_df['Review_Helpfulness'].\
map({'No': 0, 'Sometimes': 1, 'Yes': 2})
new_df.head()

new_df['New_Recommendation_Helpfulness']=new_df['Recommendation_Helpfulness'].\
map({'No': 0, 'Sometimes': 1, 'Yes': 2})
new_df.head()

new_df['New_Personalized_Recommendation_Frequency']=new_df['Personalized_Recommendation_Frequency'].\
map({'No': 0, 'Sometimes': 1, 'Yes': 2})
new_df.head()

new_df['New_Cart_Completion_Frequency']=new_df['Cart_Completion_Frequency'].\
map({'Never': 0, 'Rarely': 1, 'Sometimes': 2, 'Often':3, 'Always':4})
new_df.head()

new_df['New_Add_to_Cart_Browsing']=new_df['Add_to_Cart_Browsing'].\
map({'No': 0, 'Maybe': 1, 'Yes': 2})
new_df.head()
# Out:
#    age Review_Helpfulness Recommendation_Helpfulness  \
# 0   23                Yes                        Yes
# 1   23                Yes                  Sometimes
# 2   24                 No                         No
# 3   24                Yes                  Sometimes
# 4   22                Yes                        Yes
#
#   Personalized_Recommendation_Frequency Cart_Completion_Frequency  \
# 0                                   Yes                 Sometimes
# 1                                   Yes                     Often
# 2                                    No                 Sometimes
# 3                             Sometimes                 Sometimes
# 4                                   Yes                 Sometimes
#
#   Add_to_Cart_Browsing  Customer_Reviews_Importance  New_Review_Helpfulness  \
# 0                  Yes                            1                       2
# 1                  Yes                            1                       2
# 2                  Yes                            2                       0
# 3                Maybe                            5                       2
# 4                  Yes                            1                       2
#
#    New_Recommendation_Helpfulness  New_Personalized_Recommendation_Frequency  \
# 0                               2                                          2
# 1                               1                                          2
# 2                               0                                          0
# 3                               1                                          1
# 4                               2                                          2
#
#    New_Cart_Completion_Frequency  New_Add_to_Cart_Browsing
# 0                              2                         2
# 1                              3                         2
# 2                              2                         2
# 3                              2                         1
# 4                              2                         2

# %%
#We dropped the old columns that weren't relevant anymore as we got a new column. 


new_new_df=duckdb.sql('''
SELECT age, New_Review_Helpfulness, New_Recommendation_Helpfulness, 
New_Personalized_Recommendation_Frequency, New_Cart_Completion_Frequency, 
New_Add_to_Cart_Browsing, Customer_Reviews_Importance
FROM new_df
'''                  
).df()
new_new_df.head()
# Out:
#    age  New_Review_Helpfulness  New_Recommendation_Helpfulness  \
# 0   23                       2                               2
# 1   23                       2                               1
# 2   24                       0                               0
# 3   24                       2                               1
# 4   22                       2                               2
#
#    New_Personalized_Recommendation_Frequency  New_Cart_Completion_Frequency  \
# 0                                          2                              2
# 1                                          2                              3
# 2                                          0                              2
# 3                                          1                              2
# 4                                          2                              2
#
#    New_Add_to_Cart_Browsing  Customer_Reviews_Importance
# 0                         2                            1
# 1                         2                            1
# 2                         2                            2
# 3                         1                            5
# 4                         2                            1

# %%
#We looked for outliers for age. We know that if age is under 13, they can't make accounts to buy things. 

real_df=duckdb.sql('''
SELECT *
FROM new_new_df
WHERE age>=13
''').df()

real_df.head()
# Out:
#    age  New_Review_Helpfulness  New_Recommendation_Helpfulness  \
# 0   23                       2                               2
# 1   23                       2                               1
# 2   24                       0                               0
# 3   24                       2                               1
# 4   22                       2                               2
#
#    New_Personalized_Recommendation_Frequency  New_Cart_Completion_Frequency  \
# 0                                          2                              2
# 1                                          2                              3
# 2                                          0                              2
# 3                                          1                              2
# 4                                          2                              2
#
#    New_Add_to_Cart_Browsing  Customer_Reviews_Importance
# 0                         2                            1
# 1                         2                            1
# 2                         2                            2
# 3                         1                            5
# 4                         2                            1

# %%
# combination of 3 x variables
real_df['User_Experience'] = real_df['New_Review_Helpfulness'] + real_df['New_Recommendation_Helpfulness'] + real_df['New_Personalized_Recommendation_Frequency']
real_df.head()
# Out:
#    age  New_Review_Helpfulness  New_Recommendation_Helpfulness  \
# 0   23                       2                               2
# 1   23                       2                               1
# 2   24                       0                               0
# 3   24                       2                               1
# 4   22                       2                               2
#
#    New_Personalized_Recommendation_Frequency  New_Cart_Completion_Frequency  \
# 0                                          2                              2
# 1                                          2                              3
# 2                                          0                              2
# 3                                          1                              2
# 4                                          2                              2
#
#    New_Add_to_Cart_Browsing  Customer_Reviews_Importance  User_Experience
# 0                         2                            1                6
# 1                         2                            1                5
# 2                         2                            2                0
# 3                         1                            5                4
# 4                         2                            1                6

# %%
# x_y dataset
x_y_df = duckdb.sql('''
SELECT age, User_Experience, New_Cart_Completion_Frequency, New_Add_to_Cart_Browsing
FROM real_df
''').df()

x_y_df.head()

#We want to categorize into 5 different age groups.

real_df.loc[(real_df["age"] >= 13) & (real_df["age"] <= 18), "age"] = 1
real_df.loc[(real_df["age"] >= 19) & (real_df["age"] <= 25), "age"] = 2
real_df.loc[(real_df["age"] >= 26) & (real_df["age"] <= 40), "age"] = 3
real_df.loc[(real_df["age"] >= 41) & (real_df["age"] <= 64), "age"] = 4
real_df.loc[(real_df["age"] >= 65), "age"] = 5

age_group_df=duckdb.sql('''
SELECT x_y_df.age, x_y_df.User_Experience, x_y_df.New_Cart_Completion_Frequency, x_y_df.New_Add_to_Cart_Browsing, real_df.age AS age_group
FROM x_y_df
INNER JOIN real_df
ON x_y_df.New_Add_to_Cart_Browsing=real_df.New_Add_to_Cart_Browsing
''').df()

age_group_df.head()
# Out:
#    age  User_Experience  New_Cart_Completion_Frequency  \
# 0    2                6                              2
# 1    2                5                              3
# 2    2                0                              2
# 3    2                4                              2
# 4    2                6                              2
#
#    New_Add_to_Cart_Browsing  age_group
# 0                         2          2
# 1                         2          2
# 2                         2          2
# 3                         1          2
# 4                         2          2

# %%
# average of each column

final_df = real_df.groupby('age')[['New_Review_Helpfulness', 'New_Recommendation_Helpfulness', 'New_Personalized_Recommendation_Frequency', 'New_Cart_Completion_Frequency', 'New_Add_to_Cart_Browsing', 'Customer_Reviews_Importance']].mean()
final_df.head()
# Out:
#      New_Review_Helpfulness  New_Recommendation_Helpfulness  \
# age
# 1                  0.888889                        0.777778
# 2                  1.317647                        1.031373
# 3                  1.077982                        0.908257
# 4                  1.018692                        1.000000
# 5                  1.000000                        1.500000
#
#      New_Personalized_Recommendation_Frequency  New_Cart_Completion_Frequency  \
# age
# 1                                     0.444444                       2.277778
# 2                                     0.780392                       2.176471
# 3                                     0.779817                       2.293578
# 4                                     0.859813                       2.214953
# 5                                     1.000000                       2.500000
#
#      New_Add_to_Cart_Browsing  Customer_Reviews_Importance
# age
# 1                    0.833333                     2.500000
# 2                    1.278431                     2.407843
# 3                    1.059633                     2.490826
# 4                    0.990654                     2.616822
# 5                    0.500000                     2.500000

# %% [markdown]
# ## Explorative Analysis:

# %%
plot1 = sns.lmplot(data = age_group_df, x='User_Experience', y='New_Add_to_Cart_Browsing')
plt.title('User_Experience and New_Add_to_Cart_Browsing')
plt.show()

# %%
plot2 = sns.lmplot(data = age_group_df, x='User_Experience', y='New_Cart_Completion_Frequency')
plt.title('User_Experience and New_Cart_Completion_Frequency')
plt.show()

# %%
plot3 = sns.lmplot(data = age_group_df, x='User_Experience', y='New_Add_to_Cart_Browsing', hue='age_group')
plt.title('User_Experience and New_Add_to_Cart_Browsing in different age groups')
plt.show()
# Out:
# /Users/ashleychiang/anaconda3/envs/info2950/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/ashleychiang/anaconda3/envs/info2950/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
plot4 = sns.lmplot(data = age_group_df, x='User_Experience', y='New_Cart_Completion_Frequency', hue='age_group')
plt.title('User_Experience and New_Cart_Completion_Frequency in different age groups')
plt.show()
# Out:
# /Users/ashleychiang/anaconda3/envs/info2950/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/ashleychiang/anaconda3/envs/info2950/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# ## Data Description:

# %% [markdown]
# ### Motivation:

# %% [markdown]
# ### Data Source:

# %% [markdown]
# ## Data Limitation:

# %% [markdown]
# ## Explorative Analysis:

# %% [markdown]
# ## Questions for Reviewer:
